# %%
import emission.storage.decorations.location_queries as lq

# %%
reload(lq)
# Out:
# <module 'emission.storage.decorations.location_queries' from '/Users/shankari/e-mission/e-mission-server/emission/storage/decorations/location_queries.py'>

# %%
lq.get_uuid_list()
# Out:
# [UUID('0763de67-f61e-3f5d-90e7-518e69793954'),
#  UUID('f955cff1-8fb8-3b42-8776-6d8874e5b90a'),
#  UUID('b0d937d0-70ef-305e-9563-440369012b39')]

# %%
my_time_df_21 = lq.get_plottable_df(lq.get_uuid_list()[0], "time", None, None)

# %%
my_time_df_21.head()
# Out:
#   filter                  key  mAccuracy  mAltitude  mBearing  mDistance  \
# 0   time  background/location         15   3.000000        66          0
# 1   time  background/location         15   4.399994        28          0
# 2   time  background/location         15   4.600006        29          0
# 3   time  background/location         15   4.500000        16          0
# 4   time  background/location         15   3.899994        21          0
#
#    mElapsedRealtimeNanos mHasAccuracy mHasAltitude mHasBearing  \
# 0        144277309113963         True         True        True
# 1        144286493000000         True         True        True
# 2        144289229035838         True         True        True
# 3        144295227601512         True         True        True
# 4        144300274049266         True         True        True
#
#           ...          mLongitude  mProvider mResults   mSpeed          mTime  \
# ...

# %%
my_time_df_21.tail()
# Out:
#      filter                  key  mAccuracy  mAltitude  mBearing  mDistance  \
# 1110   time  background/location     13.760          0         0          0
# 1111   time  background/location     12.918          0         0          0
# 1112   time  background/location     11.613          0         0          0
# 1113   time  background/location     11.613          0         0          0
# 1114   time  background/location     11.130          0         0          0
#
#       mElapsedRealtimeNanos mHasAccuracy mHasAltitude mHasBearing  \
# 1110        182658841000000         True        False       False
# 1111        182663957000000         True        False       False
# 1112        182674024000000         True        False       False
# 1113        182679056000000         True        False       False
# 1114        182684058000000         True        False       False
#
#              ...          mLongitude  mProvider mResults  mSpeed  \
# ...

# %%
my_split_points_time_21 = lq.get_potential_split_index(my_time_df_21)

# %%
print my_split_points_time_21
# Out:
# Int64Index([0, 484, 494, 523, 641, 923, 935, 1030, 1040, 1080, 1091, 1104], dtype='int64')

# %%
my_time_df_21_all = lq.get_plottable_df(lq.get_uuid_list()[0], "time", None, None)

# %%
my_time_df_21_all.tail()
# Out:
#      filter                  key  mAccuracy  mAltitude  mBearing  mDistance  \
# 1543   time  background/location       37.5          0         0          0
# 1544   time  background/location       36.0          0         0          0
# 1545   time  background/location       36.0          0         0          0
# 1546   time  background/location      306.0          0         0          0
# 1547   time  background/location       37.5          0         0          0
#
#       mElapsedRealtimeNanos mHasAccuracy mHasAltitude mHasBearing  \
# 1543        259965516000000         True        False       False
# 1544        259995535000000         True        False       False
# 1545        260025570000000         True        False       False
# 1546        264820332000000         True        False       False
# 1547        265003739000000         True        False       False
#
#              ...          mLongitude  mProvider mResults  mSpeed  \
# ...

# %%
import datetime as pydt

# %%
import pytz

# %%
get_dt = lambda date: pydt.datetime(2015,7,date,tzinfo=pytz.timezone("America/Los_Angeles"))

# %%
my_time_df_21_new = lq.get_plottable_df(lq.get_uuid_list()[0], "time", get_dt(21), get_dt(22))
# Out:
# final query = {'metadata.key': 'background/location', 'user_id': UUID('0763de67-f61e-3f5d-90e7-518e69793954'), 'data.mTime': {'$lt': 1437552000000.0}, 'metadata.filter': 'time'}

# %%
my_time_df_21_new.tail()
# Out:
#      filter                  key  mAccuracy  mAltitude  mBearing  mDistance  \
# 1110   time  background/location     13.760          0         0          0
# 1111   time  background/location     12.918          0         0          0
# 1112   time  background/location     11.613          0         0          0
# 1113   time  background/location     11.613          0         0          0
# 1114   time  background/location     11.130          0         0          0
#
#       mElapsedRealtimeNanos mHasAccuracy mHasAltitude mHasBearing  \
# 1110        182658841000000         True        False       False
# 1111        182663957000000         True        False       False
# 1112        182674024000000         True        False       False
# 1113        182679056000000         True        False       False
# 1114        182684058000000         True        False       False
#
#              ...          mLongitude  mProvider mResults  mSpeed  \
# ...

# %%
import emission.analysis.plotting.leaflet_osm.our_plotter as lo

# %%
reload(lo)
# Out:
# <module 'emission.analysis.plotting.leaflet_osm.our_plotter' from '/Users/shankari/e-mission/e-mission-server/emission/analysis/plotting/leaflet_osm/our_plotter.py'>

# %%
def get_map_list(user_id, loc_filter, start_dt, end_dt):
    df = lq.get_plottable_df(user_id, loc_filter, start_dt, end_dt)
    sp = lq.get_potential_split_index(df)
    print df.formatted_time.iloc[sp]
    return lo.get_map_list(df, sp)

# %%
my_time_filter_map_list_21 = get_map_list(lq.get_uuid_list()[0], "time", get_dt(21), get_dt(22))
# Out:
# final query = {'metadata.key': 'background/location', '$and': [{'data.mTime': {'$gt': 1437465600000.0}}, {'data.mTime': {'$lt': 1437552000000.0}}], 'user_id': UUID('0763de67-f61e-3f5d-90e7-518e69793954'), 'metadata.filter': 'time'}
# 0      2015-07-21 08:22:15
# 484    2015-07-21 12:30:27
# 494    2015-07-21 13:21:30
# 523    2015-07-21 13:30:29
# 641    2015-07-21 14:41:11
# 923    2015-07-21 15:46:13
# 935    2015-07-21 15:54:49
# 1030   2015-07-21 17:38:30
# 1040   2015-07-21 18:07:49
# 1080   2015-07-21 18:19:38
# 1091   2015-07-21 18:47:23
# 1104   2015-07-21 19:00:12
# Name: formatted_time, dtype: datetime64[ns]

# %%
my_dist_filter_map_list_21 = get_map_list(lq.get_uuid_list()[0], "distance", get_dt(21), get_dt(22))
# Out:
# final query = {'metadata.key': 'background/location', '$and': [{'data.mTime': {'$gt': 1437465600000.0}}, {'data.mTime': {'$lt': 1437552000000.0}}], 'user_id': UUID('0763de67-f61e-3f5d-90e7-518e69793954'), 'metadata.filter': 'distance'}
# 0     2015-07-21 08:22:15
# 1     2015-07-21 08:46:30
# 103   2015-07-21 12:30:27
# 106   2015-07-21 13:21:30
# 112   2015-07-21 13:30:29
# 145   2015-07-21 14:41:11
# 213   2015-07-21 15:46:13
# 216   2015-07-21 15:54:49
# 235   2015-07-21 17:38:30
# 237   2015-07-21 18:07:49
# 245   2015-07-21 18:19:38
# 247   2015-07-21 18:47:23
# 251   2015-07-21 19:00:12
# Name: formatted_time, dtype: datetime64[ns]

# %%
my_dist_filter_map_list_22 = get_map_list(lq.get_uuid_list()[0], "distance", get_dt(22), get_dt(23))
# Out:
# final query = {'metadata.key': 'background/location', '$and': [{'data.mTime': {'$gt': 1437552000000.0}}, {'data.mTime': {'$lt': 1437638400000.0}}], 'user_id': UUID('0763de67-f61e-3f5d-90e7-518e69793954'), 'metadata.filter': 'distance'}
# 0     2015-07-22 08:14:53
# 59    2015-07-22 09:09:00
# 87    2015-07-22 09:26:56
# 90    2015-07-22 13:16:38
# 122   2015-07-22 14:41:15
# 128   2015-07-22 14:51:49
# 169   2015-07-22 16:02:29
# 172   2015-07-22 16:08:17
# 191   2015-07-22 17:51:17
# 195   2015-07-22 18:09:52
# Name: formatted_time, dtype: datetime64[ns]

# %%
my_time_filter_map_list_22 = get_map_list(lq.get_uuid_list()[0], "time", get_dt(22), get_dt(23))
# Out:
# final query = {'metadata.key': 'background/location', '$and': [{'data.mTime': {'$gt': 1437552000000.0}}, {'data.mTime': {'$lt': 1437638400000.0}}], 'user_id': UUID('0763de67-f61e-3f5d-90e7-518e69793954'), 'metadata.filter': 'time'}
# 0     2015-07-22 08:14:53
# 181   2015-07-22 13:16:38
# 257   2015-07-22 14:41:15
# 372   2015-07-22 16:02:29
# 431   2015-07-22 17:51:17
# Name: formatted_time, dtype: datetime64[ns]

# %%
import emission.analysis.plotting.leaflet_osm.ipython_helper as ipy

# %%
ipy.inline_map(my_time_filter_map_list_22[0])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(my_time_filter_map_list_22[1])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(my_time_filter_map_list_22[2])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(my_time_filter_map_list_22[3])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
tom_time_filter_map_list_22 = get_map_list(lq.get_uuid_list()[2], "time", get_dt(22), get_dt(23))
# Out:
# final query = {'metadata.key': 'background/location', '$and': [{'data.mTime': {'$gt': 1437552000000.0}}, {'data.mTime': {'$lt': 1437638400000.0}}], 'user_id': UUID('b0d937d0-70ef-305e-9563-440369012b39'), 'metadata.filter': 'time'}
# 0     2015-07-22 08:05:53
# 10    2015-07-22 08:26:15
# 31    2015-07-22 08:40:35
# 74    2015-07-22 17:47:30
# 114   2015-07-22 18:40:26
# 138   2015-07-22 23:14:15
# Name: formatted_time, dtype: datetime64[ns]

# %%
tom_distance_filter_map_list_22 = get_map_list(lq.get_uuid_list()[2], "distance", get_dt(22), get_dt(23))
# Out:
# final query = {'metadata.key': 'background/location', '$and': [{'data.mTime': {'$gt': 1437552000000.0}}, {'data.mTime': {'$lt': 1437638400000.0}}], 'user_id': UUID('b0d937d0-70ef-305e-9563-440369012b39'), 'metadata.filter': 'distance'}
# 0    2015-07-22 08:05:53
# 2    2015-07-22 08:26:15
# 14   2015-07-22 08:40:35
# 23   2015-07-22 08:51:06
# 29   2015-07-22 17:47:30
# 48   2015-07-22 18:40:26
# 58   2015-07-22 23:14:15
# Name: formatted_time, dtype: datetime64[ns]

# %%
ipy.inline_map(tom_time_filter_map_list_22[1])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(tom_time_filter_map_list_22[2])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(tom_time_filter_map_list_22[3])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(tom_distance_filter_map_list_22[4])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
tom_time_filter_df_22 = lq.get_plottable_df(lq.get_uuid_list()[2], "distance", get_dt(22), get_dt(23))
# Out:
# final query = {'metadata.key': 'background/location', '$and': [{'data.mTime': {'$gt': 1437552000000.0}}, {'data.mTime': {'$lt': 1437638400000.0}}], 'user_id': UUID('b0d937d0-70ef-305e-9563-440369012b39'), 'metadata.filter': 'distance'}

# %%
import numpy as np

# %%
tom_time_filter_df_22[tom_time_filter_df_22.mLatitude == 37.262226300000002][["mAccuracy", "mTime", "mElapsedRealtimeNanos"]]
# Out:
#     mAccuracy          mTime  mElapsedRealtimeNanos
# 34        978  1437612607683        798404153000000
# 36        978  1437612827651        798624121000000
# 39        978  1437612921570        798718041000000
# 44        978  1437613296848        799093319000000

# %%
my_dist_df_21 = lq.get_plottable_df(lq.get_uuid_list()[0], "distance", None, None)

# %%
my_split_points_dist_21 = lq.get_potential_split_index(my_dist_df_21)

# %%
print my_split_points_dist_21
# Out:
# Int64Index([0, 2, 103, 107, 113, 146, 213, 216, 235, 237, 245, 247, 251], dtype='int64')

# %%
dist_filter_map_list_21 = lo.get_map_list(my_dist_df_21, my_split_points_dist_21)

# %%
ipy.inline_map(dist_filter_map_list_21[0])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(dist_filter_map_list_21[1])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(dist_filter_map_list_21[2])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(dist_filter_map_list_21[3])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(dist_filter_map_list_21[4])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
tom_time_df_21 = lq.get_plottable_df(lq.get_uuid_list()[2], "time", None, None)

# %%
tom_split_points_time_21 = lq.get_potential_split_index(tom_time_df_21)

# %%
tom_time_filter_map_list_21 = lo.get_map_list(tom_time_df_21, split_points_time_21)

# %%
ipy.inline_map(tom_time_filter_map_list_21[0])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(tom_time_filter_map_list_21[1])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(tom_time_filter_map_list_21[2])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(tom_time_filter_map_list_21[3])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
tom_dist_df_21 = lq.get_plottable_df(lq.get_uuid_list()[2], "distance", None, None)
tom_split_points_dist_21 = lq.get_potential_split_index(tom_dist_df_21)
tom_dist_filter_map_list_21 = lo.get_map_list(tom_dist_df_21, tom_split_points_dist_21)

# %%
ipy.inline_map(tom_dist_filter_map_list_21[3])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(tom_dist_filter_map_list_21[4])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(tom_dist_filter_map_list_21[5])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
ipy.inline_map(tom_dist_filter_map_list_21[7])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
tom_dist_df_21.tail()
# Out:
#     filter                  key  mAccuracy  mAltitude  mBearing  mDistance  \
# 676   time  background/location     17.448          0         0          0
# 677   time  background/location     15.926          0         0          0
# 678   time  background/location     14.821          0         0          0
# 679   time  background/location     14.409          0         0          0
# 680   time  background/location     13.722          0         0          0
#
#      mElapsedRealtimeNanos mHasAccuracy mHasAltitude mHasBearing  \
# 676        716217528000000         True        False       False
# 677        716227473000000         True        False       False
# 678        716238094000000         True        False       False
# 679        716248124000000         True        False       False
# 680        716258419000000         True        False       False
#
#             ...          mLongitude  mProvider mResults  mSpeed  \
# ...

# %%
tom_dist_df_21.formatted_time.iloc[tom_split_points_dist_21]
# Out:
# 0     2015-07-21 00:56:19
# 10    2015-07-21 08:22:14
# 73    2015-07-21 08:39:27
# 126   2015-07-21 08:55:26
# 356   2015-07-21 18:01:06
# 480   2015-07-21 18:23:50
# 670   2015-07-21 18:59:00
# Name: formatted_time, dtype: datetime64[ns]

# %%
my_time_df_21_22 = lq.get_plottable_df(lq.get_uuid_list()[0], "time", None, None)
tom_split_points_dist_21 = lq.get_potential_split_index(tom_dist_df_21)
tom_dist_filter_map_list_21 = lo.get_map_list(tom_dist_df_21, tom_split_points_dist_21)
